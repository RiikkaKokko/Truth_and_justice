# %%
from pathlib import Path
import os
import io
import matplotlib.pyplot as plt
import numpy as np
import numpy
from estnltk import Text

# %%
#Go through all books
work_dir="Data/Books/"

word_lenght=[]
names=[]
for index in range(1,6):
    name="tõde_ja_õigus{index}.txt".format(index=index)
    names.append(name)
    path = os.path.join(work_dir, name)
    with open(path, mode="r", encoding="utf-8") as fd:
        content=fd.read().lower()
        print(content[:100])
        words=content.split(" ")
        num_words=len(words)
        print(num_words)
        word_lenght.append(num_words)        
print(word_lenght)
print(names)
# Out:
# ['tõde ja õigus i\na. h. tammsaare\n', '\n', '\n', 'see oli läinud aastasaja kolmanda veerandi lõpul
# 161391
# ['tõde ja õigus ii\n', '\n', '\n', '\n', 'esimest korda elus indrek tundis end tõesti üksikuna, maha
# 165277
# ['tõde ja õigus iii\n', '\n', '\n', '\n', 'soe ja sume pilvealune juulikuu hommik. öösi oli sadanud
# 124236
# ['tõde ja õigus iv\n', '\n', '\n', '\n', '„nüüd ma usun, et jumal elab alles,“ ütles karin peaaegu s
# 127780
# ['tõde ja õigus v\n', '\n', '\n', '\n', 'kui üksik rändur, kandam kaksiti õlal — pikad kummsaapad ri
# 124713
# [161391, 165277, 124236, 127780, 124713]
# ['tõde_ja_õigus1.txt', 'tõde_ja_õigus2.txt', 'tõde_ja_õigus3.txt', 'tõde_ja_õigus4.txt', 'tõde_ja_õigus5.txt']

# %%
content[:100].split()
# Out:
# ["['tõde",
#  'ja',
#  'õigus',
#  "v\\n',",
#  "'\\n',",
#  "'\\n',",
#  "'\\n',",
#  "'kui",
#  'üksik',
#  'rändur,',
#  'kandam',
#  'kaksiti',
#  'õlal',
#  '—',
#  'pikad',
#  'kummsaapad',
#  'ri']

# %%
#unikaalsed sõnad
with open("Data/Books/tõde_ja_õigus1.txt", "r") as file:
    lines = file.read().splitlines()

    uniques = set()
    for line in lines:
        uniques |= set(line.split())

    print(f"Unique words: {len(uniques)}")
# Out:
# Unique words: 33421

# %%
plt.plot(names, word_lenght)
plt.xlabel("books")
plt.ylabel("word lenght")
plt.xlim()
plt.ylim()
# Out:
# (122183.95, 167329.05)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = names
lenght = word_lenght

x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, lenght, color='grey')
plt.xlabel("Book")
plt.ylabel("word lenght")
plt.title("Word lenght by books")

plt.xticks(x_pos, x)

plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

name = names
y_pos = np.arange(len(name))
performance = word_lenght

plt.bar(y_pos, performance, align='center', alpha=0.3)
plt.xticks(y_pos, name, rotation=45,  horizontalalignment='right')
plt.ylabel('Words')
plt.title('Words count by books')

plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt  

books = names
words = word_lenght
   
fig = plt.figure(figsize = (10, 5)) 
  
# creating the bar plot 
plt.bar(books, words, color ='blue',  
        width = 0.8) 
  
plt.xlabel("book") 
plt.ylabel("Word count") 
plt.title("Word count/book") 
plt.show()

# %%
book1=Path('Data/Books/tõde_ja_õigus1.txt').read_text().lower()
book2=Path('Data/Books/tõde_ja_õigus2.txt').read_text().lower()
book3=Path('Data/Books/tõde_ja_õigus3.txt').read_text().lower()
book4=Path('Data/Books/tõde_ja_õigus4.txt').read_text().lower()
book5=Path('Data/Books/tõde_ja_õigus5.txt').read_text().lower()

# %%
words1=book1.split(" ")

# %%
num_words=len(words1)
print(num_words)
# Out:
# 161391

# %%
words2=book2.split(" ")
num_words2=len(words2)
print(num_words2)
# Out:
# 165277

# %%
#unique vs words

# %%
#https://medium.com/zareen-farooqui/harry-potter-text-analysis-4d89ffe59d5b
#https://towardsdatascience.com/basic-nlp-on-the-texts-of-harry-potter-sentiment-analysis-1b474b13651d

# %%
len(book1)
# Out:
# 1046637

# %%
len(book2)
# Out:
# 1055244

# %%
len(book3)
# Out:
# 815828

# %%
len(book4)
# Out:
# 826314

# %%
len(book5)
# Out:
# 785082

# %% [markdown]
# # Tags

# %%
text=Text((Path('Data/Books/tõde_ja_õigus1_original.txt').read_text().lower()[:1000]))

# %%
print(text)
# Out:
# Text(text="['tõde ja õigus i\\na. h. tammsaare\\n', '\\n', '\\n', 'see oli läinud aastasaja kolmanda veerandi lõpul. päike lähenes silmapiirile, seistes sedavõrd madalas, et enam ei ulatunud valgustama ei mäkke ronivat hobust, kes puutelgedega vankrit vedas, ei vankril istuvat noort naist ega ka ligi kolmekümnelist meest, kes kõndis vankri kõrval.\\n', 'varsti jõudsid teelised mäerinnakul nii kõrgele, et päikeses helendama lõid mehe nägu – laiavõitu, tugevate lõuapäradega, terassilmadega, lühikese, kuid tiheda musta habemega –, naise nukrad silmad, look ja hobuse kikkis kõrvadega pea.\\n', '„seal ta ongi, see vargamäe,“ lausus mees ja näitas käega üle soo järgmise väljamäe poole, kus lömitas rühm madalaid hooneid. „meie hooned paistavad, teiste omad seisavad mäe taga orus, sellest siis rahva suus mäe ja oru, mõisakirjas aga eespere ja tagapere. paremat kätt see männitukk seal kõrgel mäe otsas on meie oma: igavesed vanad jändrikud teised, mõned poolkuivad juba.“\\n', 'nii palju tegi m
# ...

# %%
text.postags
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-7be7df55dd29> in <module>
# ----> 1 text.postags
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/estnltk/text.py in __getattr__(self, item)
#     129
#     130         # Nothing else to resolve
# --> 131         raise AttributeError("'Text' object has no layer {!r}".format(item))
#     132
#     133     def __setitem__(self, key, value):
#
# AttributeError: 'Text' object has no layer 'postags'

# %%
text1 = Text('Ibumetin on levinud valuvaigisti.')
print(text1.postags)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-590ff644bddf> in <module>
#       1 text1 = Text('Ibumetin on levinud valuvaigisti.')
# ----> 2 print(text1.postags)
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/estnltk/text.py in __getattr__(self, item)
#     129
#     130         # Nothing else to resolve
# --> 131         raise AttributeError("'Text' object has no layer {!r}".format(item))
#     132
#     133     def __setitem__(self, key, value):
#
# AttributeError: 'Text' object has no layer 'postags'

# %%
from estnltk import Text
text = Text('Usjas kaslane ründas künklikul maastikul tünjat Tallinnfilmi režissööri')
text.get.word_texts.postags.postag_descriptions.as_dataframe
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-b525fe88475e> in <module>
#       1 from estnltk import Text
#       2 text = Text('Usjas kaslane ründas künklikul maastikul tünjat Tallinnfilmi režissööri')
# ----> 3 text.get.word_texts.postags.postag_descriptions.as_dataframe
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/estnltk/text.py in __getattr__(self, item)
#     129
#     130         # Nothing else to resolve
# --> 131         raise AttributeError("'Text' object has no layer {!r}".format(item))
#     132
#     133     def __setitem__(self, key, value):
#
# AttributeError: 'Text' object has no layer 'get'

# %%
text.get.word_texts.postags.postag_descriptions.as_list
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-96ddc8f9f739> in <module>
# ----> 1 text.get.word_texts.postags.postag_descriptions.as_list
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/estnltk/text.py in __getattr__(self, item)
#     129
#     130         # Nothing else to resolve
# --> 131         raise AttributeError("'Text' object has no layer {!r}".format(item))
#     132
#     133     def __setitem__(self, key, value):
#
# AttributeError: 'Text' object has no layer 'get'
